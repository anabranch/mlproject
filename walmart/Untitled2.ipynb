-- %%
require "nn"
-- Out:
-- {
--   Copy : table: 0x162dba40
--   test : function: 0x1636bf28
--   ConcatTable : table: 0x1631ca28
--   L1HingeEmbeddingCriterion : table: 0x162e2798
--   Module : table: 0x162b22f8
--   ClassNLLCriterion : table: 0x1604ef80
--   SpatialAveragePooling : table: 0x162f1880
--   BCECriterion : table: 0x15fac428
--   MM : table: 0x162c0500
--   StochasticGradient : table: 0x16306738
--   SpatialConvolutionMM : table: 0x15f6e7b0
--   ParallelCriterion : table: 0x15fcc0b8
--   HingeEmbeddingCriterion : table: 0x16059180
--   Reshape : table: 0x162ca6b8
--   SpatialContrastiveNormalization : table: 0x15f83980
--   Jacobian :
--     {
--       forward : function: 0x1624df08
--       testAllUpdate : function: 0x162be6c8
--       testDiagHessianInput : function: 0x16059a50
--       testDiagHessianWeight : function: 0x16059a70
--       testDiagHessianBias : function: 0x16059a90
--       testDiagHessian : function: 0x16059a30
--       testJacobian : function: 0x160599d0
-- ...

-- %%
inputs = 700; outputs = 38; HUs = 200; -- parameters

-- %%
x = nn.Sequential();  -- make a multi-layer perceptron
inputs = 700; outputs = 1; HUs = 20; -- parameters
x:add(nn.Linear(inputs, HUs))
x:add(nn.Tanh())
x:add(nn.Linear(HUs, outputs))
x:add(nn.SoftMax())
